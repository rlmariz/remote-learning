# %% [markdown]
# ![Planta Mestrado 2 Tanques.png](data:image/png;base64,...)

# %%
#keras 3
# !pip install -q tensorflow==2.16.1
# !pip install -q keras==3.3.3
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 59.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 76.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 32.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.

# %%
import os
####*IMPORANT*: Have to do this line *before* importing tensorflow
SEED = 1
os.environ['PYTHONHASHSEED']=str(SEED)

import matplotlib.pyplot as plt
from matplotlib import patches
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
from pandas import DataFrame, read_csv
import math
from keras import layers
from keras.layers import Input, LSTM, Dense, Reshape, Dropout, Lambda
from keras.models import Model, Sequential, load_model
from functools import partial
import joblib
import warnings

warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

tf.keras.backend.set_floatx('float64')
tf.keras.backend.clear_session()

def reset_random_seeds():
   os.environ['PYTHONHASHSEED']=str(SEED)
   tf.random.set_seed(SEED)
   np.random.seed(SEED)
   random.seed(SEED)

reset_random_seeds()

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

# %%
print("Versão do Keras:", keras.__version__)
print("Versão do TensorFlow:", tf.__version__)
import sys
print("Versão do Python:", sys.version)
# Out:
# Versão do Keras: 3.3.3
# Versão do TensorFlow: 2.16.1
# Versão do Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
def plot_sim_history(sim_history_x1, sim_history_x2):
  plt.figure(figsize=(16, 10))  # Define o tamanho do gráfico

  plt.subplot(3, 1, 1)
  plt.plot(sim_history_x1['x'], label='x1')
  plt.plot(sim_history_x1['ref'], label='ref1', linestyle=':')
  plt.plot(sim_history_x2['x'], label='x2')
  plt.plot(sim_history_x2['ref'], label='ref2', linestyle=':')
  plt.xlabel("Steps/Time(s)")
  plt.ylabel("Level(m)")
  plt.title('Gráfico de Controle Aprendizado Por Reforço')
  plt.legend()
  plt.grid(True)  # Adiciona uma grade ao gráfico
  plt.tight_layout()  # Ajusta o layout

  plt.subplot(3, 1, 2)
  plt.plot(sim_history_x1['qe'], label='qe')
  plt.plot(sim_history_x1['qs'], label='qs')
  plt.ylabel("(m^3/s)")
  plt.title('Gráfico de Sinal Aprendizado Por Reforço')
  plt.legend()
  plt.grid(True)  # Adiciona uma grade ao gráfico
  plt.tight_layout()  # Ajusta o layout


  plt.subplot(3, 1, 3)
  plt.plot(sim_history_x1['erro'], label='erro')
  plt.ylabel("erro (m)")
  plt.title('Gráfico de Erro Aprendizado Por Reforço')
  plt.legend()
  plt.grid(True)  # Adiciona uma grade ao gráfico
  plt.tight_layout()  # Ajusta o layout

  plt.show()

# %%
def plotting(history):
    fig = plt.figure(figsize=(16, 4))
    plt.semilogy(history.history['loss'], color = "red")
    plt.semilogy(history.history['val_loss'], color = "blue")
    red_patch = patches.Patch(color='red', label='Training')
    blue_patch = patches.Patch(color='blue', label='Validation')
    plt.legend(handles=[red_patch, blue_patch])
    plt.xlabel('Epochs')
    plt.ylabel('MSE loss')
    fig.savefig(f'{plot_name}-train-history.png', format='png', dpi=600)

# %%
# Criando o gráfico
def plot_sim_degree(sim_degree):
  fig1 = plt.figure(1, figsize=(16, 4))  # Define o tamanho do gráfico

  #fig, ax = plt.subplots()

  # Plot da variável de controle

  plt.scatter(sim_degree["l"], sim_degree["x1"]   , label='X1'            , alpha=0.5)
  plt.scatter(sim_degree["l"], sim_degree["NN_x1"], label='X1 Rede Neural', alpha=1.0, marker='+')

  plt.xticks(np.arange(0, 13, 1))
  plt.yticks(np.arange(0, 13, 1))

  # Adicionando rótulos aos eixos e título
  plt.xlabel('Nível Inicial')
  plt.ylabel('Nível Final')
  plt.title('Comportamento Processo x Modelo ao Degrau - x1')

  # Adicionando legenda
  plt.legend()

  # Exibindo o gráfico
  plt.grid(True)  # Adiciona uma grade ao gráfico
  plt.tight_layout()  # Ajusta o layout


  fig2 = plt.figure(2, figsize=(16, 4))  # Define o tamanho do gráfico

  #fig, ax = plt.subplots()

  # Plot da variável de controle
  plt.scatter(sim_degree["l"], sim_degree["x2"]   , label='X2'            , alpha=0.5)
  plt.scatter(sim_degree["l"], sim_degree["NN_x2"], label='X2 Rede Neural', alpha=1.0, marker='+')

  plt.xticks(np.arange(0, 13, 1))
  plt.yticks(np.arange(0, 13, 1))

  # Adicionando rótulos aos eixos e título
  plt.xlabel('Nível Inicial')
  plt.ylabel('Nível Final')
  plt.title('Comportamento Processo x Modelo ao Degrau - x2')

  # Adicionando legenda
  plt.legend()

  # Exibindo o gráfico
  plt.grid(True)  # Adiciona uma grade ao gráfico
  plt.tight_layout()  # Ajusta o layout

  fig1.savefig(f'{plot_name}-degree-1.png', format='png', dpi=600)
  fig2.savefig(f'{plot_name}-degree-2.png', format='png', dpi=600)

  plt.show()

# %% [markdown]
# Processo que representa um o nível de um tanque com um registro

# %%
import math

# Process Const
area = 16
max_level = 12
def tank_xdot(x, qe, valve=100, valve_k = 1):
  if x >= 0:
    qs = valve_k * (valve / 100) * math.sqrt(x)
  else:
    qs = 0
  xd = (qe - qs) / area
  return xd, qs

def tank_rk(x0, qe, valve=100, valve_k = 1, t=0.2):
  a=x0
  b=qe
  c=valve
  #call 1
  xd, qs = tank_xdot(x0, qe, valve, valve_k);
  savex0 = x0;
  phi = xd;
  x0 = savex0 + 0.5 * t * xd;

  #call two
  xd, qs = tank_xdot(x0, qe, valve, valve_k);
  phi = phi + 2 * xd;
  x0 = savex0 + 0.5 * t * xd;

  #call three
  xd, qs = tank_xdot(x0, qe, valve, valve_k);
  phi = phi + 2 * xd;
  x0 = savex0 + t * xd;

  #call four
  xd, qs = tank_xdot(x0, qe, valve, valve_k);
  x = savex0 + (phi + xd) * t / 6;

  if x < 0:
    x = 0

  if x > max_level:
    x = max_level

  if np.isnan(x):
    x = 0

  if np.isnan(qs):
    qs = 0

  return x, qs;

# %%
pd.set_option('display.max_rows', None)  # Mostrar todas as linhas
pd.set_option('display.max_columns', None)  # Mostrar todas as colunas
pd.set_option('display.width', 1000)

# %%
# Parametros Globais
np.random.seed(56)
k1 = 2
k2 = 1
ts = 0.3
model_horizon = 5
pmc_horizon = 5
num_data = 10000
data_name = f"data-{num_data}_hor-{model_horizon}_ts-{ts}"

plot_name = f'pmc_nn-2tanques_{data_name}'
path = f'/content/drive/MyDrive/Colab Notebooks/Mestrado/Final/Data/pmc_nn-2tanques_{data_name}'
if not os.path.exists(path):
  os.makedirs(path)
os.chdir(path)
print(f'O diretório  é: {os.getcwd()}')
print(f'O plot_name  é: {plot_name}')
# Out:
# O diretório  é: /content/drive/MyDrive/Colab Notebooks/Mestrado/Final/Data/pmc_nn-2tanques_data-10000_hor-5_ts-0.3
# O plot_name  é: pmc_nn-2tanques_data-10000_hor-5_ts-0.3
# 'datatrain_scaler-x_data-10000_hor-5_ts-0.3.pkl'

# %%
scaler_x_train = joblib.load(f"datatrain_scaler-x_{data_name}.pkl")
x_train = np.load(f"datatrain-x_{data_name}.npy")
y_train = np.load(f"datatrain-y_{data_name}.npy")

# %% [markdown]
# Modelo de Rede Neural

# %%
model = keras.Sequential()
model.add(keras.Input(shape=(5,)))
model.add(keras.layers.Dense(32, input_dim=5, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(2, kernel_initializer=tf.initializers.zeros))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
lr=0.001
optimizer = tf.optimizers.Adam(learning_rate=lr)
loss=tf.losses.MeanSquaredError()
metrics=[tf.metrics.MeanSquaredError()]
model.compile(loss=loss, metrics=metrics, optimizer=optimizer)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Monitora a métrica de validação
    patience=20,  # Número de épocas sem melhoria antes de parar
    restore_best_weights=True  # Restaura os pesos do modelo à melhor época
)

# %%
num_epochs=200
num_batch_size=10
history = model.fit(
            x = x_train,
            y = y_train,
            batch_size = num_batch_size,
            epochs = num_epochs,
            verbose = 1,
            callbacks=[early_stopping],
            validation_split = 0.2
          )
history
# Out:
# Epoch 1/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 2/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 3/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 4/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 5/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 6/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 7/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 8/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 9/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.3430e-04 - mean_squared_error: 8.3430e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 10/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.2938e-04 - mean_squared_error: 7.2938e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 11/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 6.7473e-04 - mean_squared_error: 6.7473e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 12/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0162e-04 - mean_squared_error: 6.0162e-04 - val_loss: 9.6716e-04 - val_mean_squared_error: 9.6716e-04
# Epoch 13/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.3960e-04 - mean_squared_error: 5.3960e-04 - val_loss: 9.0816e-04 - val_mean_squared_error: 9.0816e-04
# Epoch 14/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.9922e-04 - mean_squared_error: 4.9922e-04 - val_loss: 7.9219e-04 - val_mean_squared_error: 7.9219e-04
# Epoch 15/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7096e-04 - mean_squared_error: 4.7096e-04 - val_loss: 8.1092e-04 - val_mean_squared_error: 8.1092e-04
# Epoch 16/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 4.6113e-04 - mean_squared_error: 4.6113e-04 - val_loss: 7.8746e-04 - val_mean_squared_error: 7.8746e-04
# Epoch 17/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4240e-04 - mean_squared_error: 4.4240e-04 - val_loss: 5.5250e-04 - val_mean_squared_error: 5.5250e-04
# Epoch 18/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.0894e-04 - mean_squared_error: 4.0894e-04 - val_loss: 6.4653e-04 - val_mean_squared_error: 6.4653e-04
# Epoch 19/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.2446e-04 - mean_squared_error: 4.2446e-04 - val_loss: 5.7710e-04 - val_mean_squared_error: 5.7710e-04
# Epoch 20/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 4.1341e-04 - mean_squared_error: 4.1341e-04 - val_loss: 6.0928e-04 - val_mean_squared_error: 6.0928e-04
# Epoch 21/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.7777e-04 - mean_squared_error: 3.7777e-04 - val_loss: 5.6544e-04 - val_mean_squared_error: 5.6544e-04
# Epoch 22/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.6246e-04 - mean_squared_error: 3.6246e-04 - val_loss: 4.6520e-04 - val_mean_squared_error: 4.6520e-04
# Epoch 23/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 3.3116e-04 - mean_squared_error: 3.3116e-04 - val_loss: 5.9343e-04 - val_mean_squared_error: 5.9343e-04
# Epoch 24/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.2945e-04 - mean_squared_error: 3.2945e-04 - val_loss: 3.8697e-04 - val_mean_squared_error: 3.8697e-04
# Epoch 25/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.3078e-04 - mean_squared_error: 3.3078e-04 - val_loss: 4.0402e-04 - val_mean_squared_error: 4.0402e-04
# Epoch 26/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 3.0551e-04 - mean_squared_error: 3.0551e-04 - val_loss: 3.5000e-04 - val_mean_squared_error: 3.5000e-04
# Epoch 27/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 3.0211e-04 - mean_squared_error: 3.0211e-04 - val_loss: 3.2528e-04 - val_mean_squared_error: 3.2528e-04
# Epoch 28/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0075e-04 - mean_squared_error: 3.0075e-04 - val_loss: 2.7413e-04 - val_mean_squared_error: 2.7413e-04
# Epoch 29/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9977e-04 - mean_squared_error: 2.9977e-04 - val_loss: 3.7185e-04 - val_mean_squared_error: 3.7185e-04
# Epoch 30/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.9312e-04 - mean_squared_error: 2.9312e-04 - val_loss: 2.7192e-04 - val_mean_squared_error: 2.7192e-04
# Epoch 31/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.2453e-04 - mean_squared_error: 3.2453e-04 - val_loss: 3.1566e-04 - val_mean_squared_error: 3.1566e-04
# Epoch 32/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 3.0627e-04 - mean_squared_error: 3.0627e-04 - val_loss: 2.2407e-04 - val_mean_squared_error: 2.2407e-04
# Epoch 33/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.9561e-04 - mean_squared_error: 2.9561e-04 - val_loss: 1.7563e-04 - val_mean_squared_error: 1.7563e-04
# Epoch 34/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5620e-04 - mean_squared_error: 2.5620e-04 - val_loss: 1.9024e-04 - val_mean_squared_error: 1.9024e-04
# Epoch 35/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.7677e-04 - mean_squared_error: 2.7677e-04 - val_loss: 1.6884e-04 - val_mean_squared_error: 1.6884e-04
# Epoch 36/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.6280e-04 - mean_squared_error: 2.6280e-04 - val_loss: 2.3319e-04 - val_mean_squared_error: 2.3319e-04
# Epoch 37/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.9592e-04 - mean_squared_error: 2.9592e-04 - val_loss: 2.0609e-04 - val_mean_squared_error: 2.0609e-04
# Epoch 38/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8037e-04 - mean_squared_error: 2.8037e-04 - val_loss: 1.7881e-04 - val_mean_squared_error: 1.7881e-04
# Epoch 39/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9722e-04 - mean_squared_error: 1.9722e-04 - val_loss: 2.1977e-04 - val_mean_squared_error: 2.1977e-04
# Epoch 40/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2.3094e-04 - mean_squared_error: 2.3094e-04 - val_loss: 2.3284e-04 - val_mean_squared_error: 2.3284e-04
# Epoch 41/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.3036e-04 - mean_squared_error: 2.3036e-04 - val_loss: 3.5711e-04 - val_mean_squared_error: 3.5711e-04
# Epoch 42/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.6761e-04 - mean_squared_error: 2.6761e-04 - val_loss: 1.5779e-04 - val_mean_squared_error: 1.5779e-04
# Epoch 43/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9139e-04 - mean_squared_error: 1.9139e-04 - val_loss: 2.4133e-04 - val_mean_squared_error: 2.4133e-04
# Epoch 44/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.2226e-04 - mean_squared_error: 2.2226e-04 - val_loss: 1.8442e-04 - val_mean_squared_error: 1.8442e-04
# Epoch 45/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.0437e-04 - mean_squared_error: 2.0437e-04 - val_loss: 1.8349e-04 - val_mean_squared_error: 1.8349e-04
# Epoch 46/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.6400e-04 - mean_squared_error: 1.6400e-04 - val_loss: 1.0160e-04 - val_mean_squared_error: 1.0160e-04
# Epoch 47/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.1210e-04 - mean_squared_error: 2.1210e-04 - val_loss: 1.0106e-04 - val_mean_squared_error: 1.0106e-04
# Epoch 48/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8784e-04 - mean_squared_error: 1.8784e-04 - val_loss: 1.4701e-04 - val_mean_squared_error: 1.4701e-04
# Epoch 49/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.6246e-04 - mean_squared_error: 1.6246e-04 - val_loss: 1.9128e-04 - val_mean_squared_error: 1.9128e-04
# Epoch 50/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.0977e-04 - mean_squared_error: 2.0977e-04 - val_loss: 1.6418e-04 - val_mean_squared_error: 1.6418e-04
# Epoch 51/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8738e-04 - mean_squared_error: 1.8738e-04 - val_loss: 1.3765e-04 - val_mean_squared_error: 1.3765e-04
# Epoch 52/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.4823e-04 - mean_squared_error: 1.4823e-04 - val_loss: 2.1460e-04 - val_mean_squared_error: 2.1460e-04
# Epoch 53/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1035e-04 - mean_squared_error: 2.1035e-04 - val_loss: 1.7280e-04 - val_mean_squared_error: 1.7280e-04
# Epoch 54/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5320e-04 - mean_squared_error: 1.5320e-04 - val_loss: 2.2164e-04 - val_mean_squared_error: 2.2164e-04
# Epoch 55/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.6866e-04 - mean_squared_error: 1.6866e-04 - val_loss: 1.6514e-04 - val_mean_squared_error: 1.6514e-04
# Epoch 56/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6030e-04 - mean_squared_error: 1.6030e-04 - val_loss: 1.3387e-04 - val_mean_squared_error: 1.3387e-04
# Epoch 57/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5342e-04 - mean_squared_error: 1.5342e-04 - val_loss: 1.9056e-04 - val_mean_squared_error: 1.9056e-04
# Epoch 58/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.9203e-04 - mean_squared_error: 1.9203e-04 - val_loss: 1.3480e-04 - val_mean_squared_error: 1.3480e-04
# Epoch 59/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4604e-04 - mean_squared_error: 1.4604e-04 - val_loss: 1.3024e-04 - val_mean_squared_error: 1.3024e-04
# Epoch 60/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8180e-04 - mean_squared_error: 1.8180e-04 - val_loss: 1.8532e-04 - val_mean_squared_error: 1.8532e-04
# Epoch 61/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4414e-04 - mean_squared_error: 1.4414e-04 - val_loss: 1.4696e-04 - val_mean_squared_error: 1.4696e-04
# Epoch 62/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.7415e-04 - mean_squared_error: 1.7415e-04 - val_loss: 2.0943e-04 - val_mean_squared_error: 2.0943e-04
# Epoch 63/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.0217e-04 - mean_squared_error: 2.0217e-04 - val_loss: 1.0271e-04 - val_mean_squared_error: 1.0271e-04
# Epoch 64/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5492e-04 - mean_squared_error: 1.5492e-04 - val_loss: 9.2199e-05 - val_mean_squared_error: 9.2199e-05
# Epoch 65/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.5804e-04 - mean_squared_error: 1.5804e-04 - val_loss: 9.8749e-05 - val_mean_squared_error: 9.8749e-05
# Epoch 66/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.0293e-04 - mean_squared_error: 1.0293e-04 - val_loss: 2.9330e-04 - val_mean_squared_error: 2.9330e-04
# Epoch 67/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.1712e-04 - mean_squared_error: 3.1712e-04 - val_loss: 7.3912e-05 - val_mean_squared_error: 7.3912e-05
# Epoch 68/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.5384e-05 - mean_squared_error: 9.5384e-05 - val_loss: 8.9349e-05 - val_mean_squared_error: 8.9349e-05
# Epoch 69/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9715e-04 - mean_squared_error: 1.9715e-04 - val_loss: 8.9062e-05 - val_mean_squared_error: 8.9062e-05
# Epoch 70/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.0516e-04 - mean_squared_error: 1.0516e-04 - val_loss: 7.5633e-05 - val_mean_squared_error: 7.5633e-05
# Epoch 71/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.2431e-04 - mean_squared_error: 1.2431e-04 - val_loss: 9.7269e-05 - val_mean_squared_error: 9.7269e-05
# Epoch 72/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.3678e-04 - mean_squared_error: 1.3678e-04 - val_loss: 1.0765e-04 - val_mean_squared_error: 1.0765e-04
# Epoch 73/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2752e-04 - mean_squared_error: 1.2752e-04 - val_loss: 1.4552e-04 - val_mean_squared_error: 1.4552e-04
# Epoch 74/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.3826e-04 - mean_squared_error: 1.3826e-04 - val_loss: 1.6162e-04 - val_mean_squared_error: 1.6162e-04
# Epoch 75/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4289e-04 - mean_squared_error: 1.4289e-04 - val_loss: 1.3922e-04 - val_mean_squared_error: 1.3922e-04
# Epoch 76/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.1851e-04 - mean_squared_error: 1.1851e-04 - val_loss: 1.4262e-04 - val_mean_squared_error: 1.4262e-04
# Epoch 77/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.3930e-04 - mean_squared_error: 1.3930e-04 - val_loss: 1.5385e-04 - val_mean_squared_error: 1.5385e-04
# Epoch 78/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.1055e-04 - mean_squared_error: 1.1055e-04 - val_loss: 1.4027e-04 - val_mean_squared_error: 1.4027e-04
# Epoch 79/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.7367e-04 - mean_squared_error: 1.7367e-04 - val_loss: 1.4643e-04 - val_mean_squared_error: 1.4643e-04
# Epoch 80/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.2290e-04 - mean_squared_error: 1.2290e-04 - val_loss: 1.1360e-04 - val_mean_squared_error: 1.1360e-04
# Epoch 81/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2701e-04 - mean_squared_error: 1.2701e-04 - val_loss: 1.4309e-04 - val_mean_squared_error: 1.4309e-04
# Epoch 82/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.2410e-04 - mean_squared_error: 1.2410e-04 - val_loss: 1.2262e-04 - val_mean_squared_error: 1.2262e-04
# Epoch 83/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.0088e-04 - mean_squared_error: 1.0088e-04 - val_loss: 1.3853e-04 - val_mean_squared_error: 1.3853e-04
# Epoch 84/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.1116e-04 - mean_squared_error: 1.1116e-04 - val_loss: 2.9887e-04 - val_mean_squared_error: 2.9887e-04
# Epoch 85/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.7680e-04 - mean_squared_error: 1.7680e-04 - val_loss: 1.2222e-04 - val_mean_squared_error: 1.2222e-04
# Epoch 86/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0404e-04 - mean_squared_error: 1.0404e-04 - val_loss: 1.5243e-04 - val_mean_squared_error: 1.5243e-04
# Epoch 87/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4072e-04 - mean_squared_error: 1.4072e-04 - val_loss: 1.3021e-04 - val_mean_squared_error: 1.3021e-04

# %%
if not os.path.exists(path):
  os.makedirs(path)
os.chdir(path)
print(f'O diretório  é: {os.getcwd()}')
path = f'/content/drive/MyDrive/Colab Notebooks/Mestrado/Final/Data/pmc_nn-2tanques_{data_name}-ketas3'
# Out:
# O diretório  é: /content/drive/MyDrive/Colab Notebooks/Mestrado/Final/Data/pmc_nn-2tanques_data-10000_hor-5_ts-0.3-ketas3

# %%
plotting(history)

# %% [markdown]
# Simulação Degrau Unitário para verificar se a rede neural tem comportamento semelhante ao processo.

# %%
sim_degree_columns = ["l","qe", "qc", "qs", "x1", "x2", "NN_x1", "NN_x2"]
sim_degree = []

qe = 2.0;
vc = 100
vs = 100
t = 0

for l in range(13):
  t+=1

  x1 = l;
  x2 = l;
  NN_x1 = l;
  NN_x2 = l;

  for _ in range(int(pmc_horizon/model_horizon)):
    NN_in = np.array([[NN_x1, qe, vc, NN_x2, vs]])
    NN_in = scaler_x_train.transform(NN_in)
    NN_pred = model.predict(NN_in, verbose = None);

    NN_x1 += NN_pred[0][0]
    NN_x2 += NN_pred[0][1]

  for _ in range(pmc_horizon):
    x1, qc = tank_rk(x1, qe, vc, k1, ts)
    x2, qs = tank_rk(x2, qc, vs, k2, ts)

  sim_degree.append([l, qe, qc, qs, x1, x2, NN_x1, NN_x2])
sim_degree = pd.DataFrame(data = sim_degree, columns = sim_degree_columns)
sim_degree.to_csv('sim_degree.csv', index=False)
sim_degree
# Out:
#      l   qe        qc        qs         x1         x2      NN_x1      NN_x2
# 0    0  2.0  0.746171  0.205284   0.139192   0.042142   0.079443   0.060448
# 1    1  2.0  2.000000  1.044805   1.000000   1.091618   1.000770   1.098282
# 2    2  2.0  2.774793  1.458572   1.924869   2.127432   1.922239   2.134758
# 3    3  2.0  3.386099  1.776473   2.866416   3.155857   2.858951   3.164490
# 4    4  2.0  3.907357  2.044542   3.816860   4.180152   3.820571   4.181707
# 5    5  2.0  4.369469  2.280728   4.773065   5.201718   4.781644   5.203812
# 6    6  2.0  4.788901  2.494255   5.733394   6.221308   5.737567   6.228959
# 7    7  2.0  5.175660  2.690610   6.696864   7.239381   6.696847   7.246700
# 8    8  2.0  5.536363  2.873368   7.662829   8.256244   7.666423   8.258862
# 9    9  2.0  5.875658  3.045014   8.630839   9.272111   8.637042   9.271593
# 10  10  2.0  6.196955  3.207357   9.600564  10.287140   9.597933  10.284756
# 11  11  2.0  6.502847  3.361763  10.571754  11.301451  10.576198  11.305671
# 12  12  2.0  6.795356  3.473093  11.544216  12.000000  11.543201  11.980489

# %%
 plot_sim_degree(sim_degree)

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
